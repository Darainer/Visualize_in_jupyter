# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from IPython.display import HTML
import os

#from generate_video import generate_video
from visualize_crossing_vehicle_accident import visualize_crossing_vehicle_accident, plot_vehicle

# %%
# Example motion data
vehicle_a_data = np.array([[i, 10] for i in range(20)])  # Vehicle A moving vertically
vehicle_b_data = np.array([[10, i] for i in range(20)])  # Vehicle B moving horizontally


visualize_crossing_vehicle_accident(vehicle_a_data, vehicle_b_data)
animation = visualize_crossing_vehicle_accident(vehicle_a_data, vehicle_b_data)
HTML(animation.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-ff96c3305866> in <module>
#       4
#       5
# ----> 6 visualize_crossing_vehicle_accident(vehicle_a_data, vehicle_b_data)
#       7 animation = visualize_crossing_vehicle_accident(vehicle_a_data, vehicle_b_data)
#       8 HTML(animation.to_jshtml())
#
# ~/repos/Visualize_in_jupyter/visualize_crossing_vehicle_accident.py in visualize_crossing_vehicle_accident(vehicle_a_data, vehicle_b_data, vehicle_a_dim, vehicle_b_dim, fov_angle)
#      17     vehicle_a_patch = patches.Rectangle((0, 0), vehicle_a_dim[0], vehicle_a_dim[1], angle=0, color='red', label='Vehicle A')
#      18     vehicle_b_patch = patches.Rectangle((0, 0), vehicle_b_dim[0], vehicle_b_dim[1], angle=90, color='blue', label='Vehicle B')
# ---> 19     vehicle_a_fov_patch = patches.Polygon(xy=[], facecolor='gray', alpha=0.3)
#      20
#      21     def init():
#
# ~/.local/lib/python3.6/site-packages/matplotlib/patches.py in __init__(self, xy, closed, **kwargs)
#    1020         Patch.__init__(self, **kwargs)
#    1021         self._closed = closed
# -> 1022         self.set_xy(xy)
#    1023
#    1024     def get_path(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/patches.py in set_xy(self, xy)
#    1073         """
#    1074         xy = np.asarray(xy)
# -> 1075         nverts, _ = xy.shape
#    1076         if self._closed:
#    1077             # if the first and last vertex are the "same", then we assume that
#
# ValueError: not enough values to unpack (expected 2, got 1)
