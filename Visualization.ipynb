# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from IPython.display import HTML
import os

#from generate_video import generate_video
from visualize_crossing_vehicle_accident import visualize_crossing_vehicle_accident, plot_vehicle

# %%
# Vehicle motion data:  
#   offset for collision at front door
#   different velocity ratios possible 20kph / 60kph (3X)
vehicle_a_data = np.array([[3+ i, 20] for i in range(20)])  # Vehicle A moving vertically
vehicle_b_data = np.array([[15, 3*i] for i in range(20)])  # Vehicle B moving horizontally

animation = visualize_crossing_vehicle_accident(vehicle_a_data, vehicle_b_data, fov_angle=120)
HTML(animation.to_jshtml())
# Out:
# No handles with labels found to put in legend.
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
# ...
